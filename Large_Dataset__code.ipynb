# %% [markdown]
# ### 코랩에서 kaggle dataset 사용하는 방법
# [https://soohee410.github.io/colab_kaggle](https://soohee410.github.io/colab_kaggle)
#
# [https://kubig-2021-2.tistory.com/35](https://kubig-2021-2.tistory.com/35)

# %%
# kaggle 설치
# !pip install kaggle
from google.colab import files
files.upload() # kaggle.json 업로드
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      <input type="file" id="files-72157f23-441d-4f54-92ac-497014bb3b4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72157f23-441d-4f54-92ac-497014bb3b4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"leeeeeyeon","key":"1a93fb45fd5f8f4182bd2da22f527ae4"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# 데이터셋 다운로드
# !kaggle datasets download -d anilkrsah/deepmushroom
# Out:
# ...
# 100% 1.33G/1.33G [00:05<00:00, 227MB/s]
# 100% 1.33G/1.33G [00:05<00:00, 238MB/s]

# %%
# !unzip deepmushroom.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: Mushrooms/Exidia/BWP2010PIC30954525.jpg
#   inflating: Mushrooms/Exidia/BWP2010PIC63422920.jpg
#   inflating: Mushrooms/Exidia/BWP2010PIC64941478.jpg
#   inflating: Mushrooms/Exidia/BWP2010PIC87748978.jpg
#   inflating: Mushrooms/Exidia/BWP2011PIC22815150.jpg
#   inflating: Mushrooms/Exidia/BWP2011PIC29916680.jpg
#   inflating: Mushrooms/Exidia/BWP2011PIC64119430.jpg
#   inflating: Mushrooms/Exidia/BWP2011PIC66469304.jpg
#   inflating: Mushrooms/Exidia/BWP2011PIC79488244.jpg
#   inflating: Mushrooms/Exidia/BWP2012PIC20482302.jpg
#   inflating: Mushrooms/Exidia/BWP2012PIC22881773.jpg
#   inflating: Mushrooms/Exidia/BWP2012PIC24301757.jpg
#   inflating: Mushrooms/Exidia/BWP2012PIC28871762.jpg
#   inflating: Mushrooms/Exidia/BWP2012PIC31608901.jpg
#   inflating: Mushrooms/Exidia/BWP2012PIC43776562.jpg
#   inflating: Mushrooms/Exidia/BWP2012PIC57928821.jpg
#   inflating: Mushrooms/Exidia/BWP2012PIC58351773.jpg
# ...

# %%
# 의미 없는 데이터 삭제
# !rm /content/Mushrooms/Agaricus/249_moW6X1JYYoE.jpg
# !rm /content/Mushrooms/Agaricus/LSA2011PIC66956658.jpg
# !rm /content/Mushrooms/Agaricus/MIH2017-9194887_HkbMzxxy7Z.jpg

# !rm /content/Mushrooms/Amanita/176_PVwGipTxo6o.jpg

# !rm /content/Mushrooms/Boletus/0051_rBIC-Uy9KzI.jpg
# !rm /content/Mushrooms/Boletus/0105_7lVm0lLO6FQ.jpg
# !rm /content/Mushrooms/Boletus/0323_WBZiJM2oR3E.jpg
# !rm /content/Mushrooms/Boletus/0572_zdESww0j-to.jpg
# !rm /content/Mushrooms/Boletus/0573_O4Ftoobc-mM.jpg
# !rm /content/Mushrooms/Boletus/0580_XJy5rZKZNaw.jpg
# !rm /content/Mushrooms/Boletus/0654_S0ZETeWMBPU.jpg
# !rm /content/Mushrooms/Boletus/0726_wNJGG_syL80.jpg
# !rm /content/Mushrooms/Boletus/0866_tzBl5y7sU6U.jpg
# !rm /content/Mushrooms/Boletus/0867_ExxTC0iGbxI.jpg
# !rm /content/Mushrooms/Boletus/0942_jGbqpjkjDyE.jpg
# !rm /content/Mushrooms/Boletus/1036_4kWl9z7sQIY.jpg
# !rm /content/Mushrooms/Boletus/1089_w6ZIiR_aoPo.jpg

# !rm /content/Mushrooms/Cortinarius/424__yIKb6VlkHQ.jpg
# !rm /content/Mushrooms/Cortinarius/547_fKznDHbWCkk.jpg
# !rm /content/Mushrooms/Cortinarius/603_WZTi2tXV188.jpg
# !rm /content/Mushrooms/Cortinarius/601_7fASYc14WTQ.jpg
# !rm /content/Mushrooms/Cortinarius/615_EIk9vAX95nQ.jpg
# !rm /content/Mushrooms/Cortinarius/660_qqPWIG-_atg.jpg
# !rm /content/Mushrooms/Cortinarius/661_VvRbIhvwAWg.jpg
# !rm /content/Mushrooms/Cortinarius/805_9ydEqufhMtk.jpg
# !rm /content/Mushrooms/Cortinarius/910_q20nsdIX9Zo.jpg
# !rm /content/Mushrooms/Cortinarius/919_KmB7cv33TjM.jpg
# !rm /content/Mushrooms/Cortinarius/920_wzMtMlkv4bE.jpg
# !rm /content/Mushrooms/Cortinarius/921_InRVQADtZNo.jpg

# !rm /content/Mushrooms/Entoloma/024_bN9lzk7miXk.jpg
# !rm /content/Mushrooms/Entoloma/068_2wjj0gUVA3U.jpg
# !rm /content/Mushrooms/Entoloma/BT2014PIC54699967.jpg
# !rm /content/Mushrooms/Entoloma/BT2014PIC57857120.jpg
# !rm /content/Mushrooms/Entoloma/DB2013PIC15319496.jpg
# !rm /content/Mushrooms/Entoloma/DB2013PIC40106344.jpg
# !rm /content/Mushrooms/Entoloma/DB2015PIC14436834.jpg
# !rm /content/Mushrooms/Entoloma/LSA2009PIC38348464.jpg
# !rm /content/Mushrooms/Entoloma/MAV2017-9222481_r14yvff2-.jpg
# !rm /content/Mushrooms/Entoloma/ML2010PIC52393875.jpg
# !rm /content/Mushrooms/Entoloma/ML2011PIC43605199.jpg
# !rm /content/Mushrooms/Entoloma/ML2011PIC46701511.jpg
# !rm /content/Mushrooms/Entoloma/ML2012PIC61127582.jpg
# !rm /content/Mushrooms/Entoloma/ML2015PIC71680457.jpg
# !rm /content/Mushrooms/Entoloma/MTO2016-9181779_ryxbXjSjgl.jpg
# !rm /content/Mushrooms/Entoloma/TKH2012PIC82223190.jpg
# !rm /content/Mushrooms/Entoloma/TKH2017-9191680_Hyz17oD1-.jpg
# !rm /content/Mushrooms/Entoloma/TKH2017-9191680_r1efymjwJZ.jpg

# !rm /content/Mushrooms/Exidia/BT2015PIC89793143.jpg
# !rm /content/Mushrooms/Exidia/BWP2017-9188187_ryegESJfsg.jpg
# !rm /content/Mushrooms/Exidia/BWP2017-9188187_BkeVrkGsl.jpg
# !rm /content/Mushrooms/Exidia/ML2011PIC65179349.jpg
# !rm /content/Mushrooms/Exidia/TKH2015PIC23528165.jpg
# !rm /content/Mushrooms/Exidia/TL2015PIC78286870.jpg
# !rm /content/Mushrooms/Exidia/TS2016PIC22327174.jpg
# !rm /content/Mushrooms/Exidia/TS2016PIC24028652.jpg
# !rm /content/Mushrooms/Exidia/TS2016PIC39839225.jpg
# !rm /content/Mushrooms/Exidia/TS2016PIC61675928.jpg

# !rm /content/Mushrooms/Hygrocybe/PTP2017-9210858_BkgS1WpB5b.jpg
# !rm /content/Mushrooms/Hygrocybe/TKH2013PIC45433874.jpg
# !rm /content/Mushrooms/Hygrocybe/BWP2011PIC73295611.jpg
# !rm /content/Mushrooms/Hygrocybe/CL2011PIC32564735.jpg
# !rm /content/Mushrooms/Hygrocybe/CL2011PIC55659604.jpg
# !rm /content/Mushrooms/Hygrocybe/FS2012PIC73542880.jpg
# !rm /content/Mushrooms/Hygrocybe/FS2016-9175449_rJegY8uNp.jpg
# !rm /content/Mushrooms/Hygrocybe/JCS2013PIC50081502.jpg
# !rm /content/Mushrooms/Hygrocybe/JM2013PIC15240112.jpg
# !rm /content/Mushrooms/Hygrocybe/JM2013PIC17348280.jpg

# !rm /content/Mushrooms/Inocybe/JM2016-9180793_SJlvh1dfee.jpg
# !rm /content/Mushrooms/Inocybe/JM2016-9181298_SyeMvXP8ee.jpg
# !rm /content/Mushrooms/Inocybe/JM2017-9200086_HkgcxFo28W.jpg
# !rm /content/Mushrooms/Inocybe/JM2017-9200086_rkceKj2LZ.jpg
# !rm /content/Mushrooms/Inocybe/JM2017-9201563_BkemZ2kIwZ.jpg
# !rm /content/Mushrooms/Inocybe/JM2017-9205453_BJx3ucfsuW.jpg
# !rm /content/Mushrooms/Inocybe/LSA2010PIC48458733.jpg
# !rm /content/Mushrooms/Inocybe/MACH2016-9184283_HJo7tu67x.jpg
# !rm /content/Mushrooms/Inocybe/MACH2016-9184283_S1eoXt_a7g.jpg
# !rm /content/Mushrooms/Inocybe/ML2011PIC13950885.jpg
# !rm /content/Mushrooms/Inocybe/ML2011PIC44452982.jpg
# !rm /content/Mushrooms/Inocybe/ML2011PIC59951286.jpg
# !rm /content/Mushrooms/Inocybe/ML2011PIC61372405.jpg
# !rm /content/Mushrooms/Inocybe/ML2011PIC83958975.jpg
# !rm /content/Mushrooms/Inocybe/ML2011PIC85209437.jpg
# !rm /content/Mushrooms/Inocybe/ML2012PIC14635592.jpg
# !rm /content/Mushrooms/Inocybe/ML2012PIC15959384.jpg
# !rm /content/Mushrooms/Inocybe/ML2012PIC22761030.jpg
# !rm /content/Mushrooms/Inocybe/ML2012PIC48582106.jpg
# !rm /content/Mushrooms/Inocybe/ML2012PIC73599746.jpg
# !rm /content/Mushrooms/Inocybe/MTO2016-9172882_SklsJWLg3.jpg
# !rm /content/Mushrooms/Inocybe/TB2011PIC11178337.jpg
# !rm /content/Mushrooms/Inocybe/TB2011PIC57440003.jpg
# !rm /content/Mushrooms/Inocybe/TGFOTO2013PIC13444463.jpg
# !rm /content/Mushrooms/Inocybe/TKH2013PIC32161814.jpg
# !rm /content/Mushrooms/Inocybe/TKH2013PIC34762032.jpg
# !rm /content/Mushrooms/Inocybe/TKH2013PIC75751454.jpg
# !rm /content/Mushrooms/Inocybe/TKH2013PIC81531401.jpg
# !rm /content/Mushrooms/Inocybe/TKH2014PIC26734770.jpg
# !rm /content/Mushrooms/Inocybe/TL2015-719591_Bkli4OAP.jpg
# !rm /content/Mushrooms/Inocybe/TL2015-719591_rJxgiN_0P.jpg
# !rm /content/Mushrooms/Inocybe/TOB2016-9177959_H1K6HZVJx.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9202157_ByENSjCOPb.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9202157_HJMEroCdwb.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9202157_Hyg4BsAuvZ.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9202157_SJH4BiA_P-.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9202157_SyUESjRdvb.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9202157_SyZVSiROv-.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9202157_rkQEriRdDb.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_BJI8SxBgcb.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_BkuLHgSxqb.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_BySIHxHg5-.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_BybLHgBe9Z.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_H148Hxrx5-.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_Hy9LSxSe5Z.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_HymLSgSxc-.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_SJP8Sere9-.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_SyKIrgHxqW.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_rJG8reBe5Z.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_rJlUreBecZ.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9208818_rk8Serx5W.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9216924_ByfGC_uIj-.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9216924_r1bGAOdUo-.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9216924_rJlMC_uLiZ.jpg
# !rm /content/Mushrooms/Inocybe/TOB2017-9216924_rkfA_O8iZ.jpg
# !rm /content/Mushrooms/Inocybe/TRL2017-9200199_SJgwmt7AIW.jpg
# !rm /content/Mushrooms/Inocybe/TRL2017-9200199_r1vmKmA8-.jpg
# !rm /content/Mushrooms/Inocybe/TRL2017-9200888_SkN46TPfwW.jpg
# !rm /content/Mushrooms/Inocybe/TRL2017-9200978_rkMDsQf7PZ.jpg
# !rm /content/Mushrooms/Inocybe/TRL2017-9205078_H1fznVtadb.jpg
# !rm /content/Mushrooms/Inocybe/TRL2017-9205078_HJ-f2Vt6u-.jpg
# !rm /content/Mushrooms/Inocybe/TRL2017-9205078_HkeMnVFTdW.jpg
# !rm /content/Mushrooms/Inocybe/TRL2017-9205078_ryf3VKTOb.jpg
# !rm /content/Mushrooms/Inocybe/TS2016-9169502_S1xdt98kF.jpg
# !rm /content/Mushrooms/Inocybe/TS2016-9169502_SydKqIkt.jpg
# !rm /content/Mushrooms/Inocybe/TS2016-9180197_Byl3-w7pJl.jpg
# !rm /content/Mushrooms/Inocybe/TS2016-9180197_S1b2-Dmpye.jpg
# Out:
# rm: cannot remove '/content/Mushrooms/Agaricus/LSA2011PIC66956658.jpg': No such file or directory
# rm: cannot remove '/content/Mushrooms/Agaricus/MIH2017-9194887_HkbMzxxy7Z.jpg': No such file or directory
# rm: cannot remove '/content/Mushrooms/Hygrocybe/BWP2011PIC73295611.jpg': No such file or directory
# rm: cannot remove '/content/Mushrooms/Hygrocybe/CL2011PIC32564735.jpg': No such file or directory
# rm: cannot remove '/content/Mushrooms/Hygrocybe/CL2011PIC55659604.jpg': No such file or directory
# rm: cannot remove '/content/Mushrooms/Hygrocybe/FS2012PIC73542880.jpg': No such file or directory
# rm: cannot remove '/content/Mushrooms/Hygrocybe/FS2016-9175449_rJegY8uNp.jpg': No such file or directory
# rm: cannot remove '/content/Mushrooms/Hygrocybe/JCS2013PIC50081502.jpg': No such file or directory
# rm: cannot remove '/content/Mushrooms/Hygrocybe/JM2013PIC15240112.jpg': No such file or directory
# ...

# %%
# 라이브러리를 한 번에 import
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn # 손실, 활성화 함수, 신경망 생성을 위한 풀링 함수 포함
from torch import optim # optimizer
import torch.nn.functional as F
from torchvision import datasets, transforms, models

from torchvision import transforms
from torchvision import datasets

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

import random
import shutil

# %%
import os
from os import path
import glob

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
device = torch.device("cuda" if torch.cuda.is_available() 
                                  else "cpu")
# pre-trained model 불러오기
# 이미지 분류 문제를 해결할 수 있도록 규모가 큰 데이터로 미리 학습된 모델
model = models.resnet152(pretrained=True)
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
#   0%|          | 0.00/230M [00:00<?, ?B/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
mushrooms = ['Agaricus', 'Amanita', 'Boletus', 'Cortinarius', 'Entoloma', 'Exidia', 'Hygrocybe', 'Inocybe', 'Lactarius', 'Pluteus', 'Russula', 'Suillus']
path = '/content/Mushrooms'

# 각각 디렉토리 내에 있는 파일들을 리스트에 저장
Agaricus = glob.glob(path+'/Agaricus'+'/*')
Amanita = glob.glob(path+'/Amanita'+'/*')
Boletus = glob.glob(path+'/Boletus'+'/*')
Cortinarius = glob.glob(path+'/Cortinarius'+'/*')
Entoloma = glob.glob(path+'/Entoloma'+'/*')
Exidia = glob.glob(path+'/Exidia'+'/*')
Hygrocybe = glob.glob(path+'/Hygrocybe'+'/*')
Inocybe = glob.glob(path+'/Inocybe'+'/*')
Lactarius = glob.glob(path+'/Lactarius'+'/*')
Pluteus = glob.glob(path+'/Pluteus'+'/*')
Russula = glob.glob(path+'/Russula'+'/*')
Suillus = glob.glob(path+'/Suillus'+'/*')

# %%
# 원본 dataset의 이미지 개수 출력
sum = 0
for elem in mushrooms:
  elem_name = elem
  elem_list = globals()[elem]
  print(f'{elem_name} 이미지 개수: {len(elem_list)}개')
  sum += len(elem_list)
print(f'총 이미지 개수: {sum}')
# Out:
# Agaricus 이미지 개수: 975개
# Amanita 이미지 개수: 749개
# Boletus 이미지 개수: 1060개
# Cortinarius 이미지 개수: 824개
# Entoloma 이미지 개수: 821개
# Exidia 이미지 개수: 425개
# Hygrocybe 이미지 개수: 742개
# Inocybe 이미지 개수: 551개
# Lactarius 이미지 개수: 1087개
# Pluteus 이미지 개수: 441개
# Russula 이미지 개수: 1073개
# Suillus 이미지 개수: 661개
# 총 이미지 개수: 9409

# %%
# train, valid, test 폴더 생성
# !mkdir train
# !mkdir valid
# !mkdir test

# %%
# train, valid, test 폴더 안에 각각 클래스별 하위 폴더 생성
# %cd /content/test
for mushroom in mushrooms:
  os.mkdir(mushroom)

# %cd /content/train
for mushroom in mushrooms:
  os.mkdir(mushroom)  

# %cd /content/valid
for mushroom in mushrooms:
  os.mkdir(mushroom)
# Out:
# /content/test
# /content/train
# /content/valid

# %%
# 본격적으로 data split을 하기 전에 test, valid 데이터셋에 몇 장이 들어가는지 계산하여 출력

# valid dataset
valid_ratio = 0.2
Agaricus_valid_count = round(len(Agaricus)*valid_ratio)
Amanita_valid_count = round(len(Amanita)*valid_ratio)
Boletus_valid_count = round(len(Boletus)*valid_ratio)
Cortinarius_valid_count = round(len(Cortinarius)*valid_ratio)
Entoloma_valid_count = round(len(Entoloma)*valid_ratio)
Exidia_valid_count = round(len(Exidia)*valid_ratio)
Hygrocybe_valid_count = round(len(Hygrocybe)*valid_ratio)
Inocybe_valid_count = round(len(Inocybe)*valid_ratio)
Lactarius_valid_count = round(len(Lactarius)*valid_ratio)
Pluteus_valid_count = round(len(Pluteus)*valid_ratio)
Russula_valid_count = round(len(Russula)*valid_ratio)
Suillus_valid_count = round(len(Suillus)*valid_ratio)

for elem in mushrooms:
  print(f'{elem} valid 파일에 들어가는 이미지 개수:', end= ' ')
  print(globals()[elem+'_valid_count'], end=' / ')
  print(len(globals()[elem]))

print('\n')

# test dataset
test_ratio = 0.2
Agaricus_test_count = round(len(Agaricus)*test_ratio)
Amanita_test_count = round(len(Amanita)*test_ratio)
Boletus_test_count = round(len(Boletus)*test_ratio)
Cortinarius_test_count = round(len(Cortinarius)*test_ratio)
Entoloma_test_count = round(len(Entoloma)*test_ratio)
Exidia_test_count = round(len(Exidia)*test_ratio)
Hygrocybe_test_count = round(len(Hygrocybe)*test_ratio)
Inocybe_test_count = round(len(Inocybe)*test_ratio)
Lactarius_test_count = round(len(Lactarius)*test_ratio)
Pluteus_test_count = round(len(Pluteus)*test_ratio)
Russula_test_count = round(len(Russula)*test_ratio)
Suillus_test_count = round(len(Suillus)*test_ratio)

for elem in mushrooms:
  print(f'{elem} test 파일에 들어가는 이미지 개수:', end= ' ')
  print(globals()[elem+'_test_count'], end=' / ')
  print(len(globals()[elem]))
# Out:
# Agaricus valid 파일에 들어가는 이미지 개수: 195 / 975
# Amanita valid 파일에 들어가는 이미지 개수: 150 / 749
# Boletus valid 파일에 들어가는 이미지 개수: 212 / 1060
# Cortinarius valid 파일에 들어가는 이미지 개수: 165 / 824
# Entoloma valid 파일에 들어가는 이미지 개수: 164 / 821
# Exidia valid 파일에 들어가는 이미지 개수: 85 / 425
# Hygrocybe valid 파일에 들어가는 이미지 개수: 148 / 742
# Inocybe valid 파일에 들어가는 이미지 개수: 110 / 551
# Lactarius valid 파일에 들어가는 이미지 개수: 217 / 1087
# Pluteus valid 파일에 들어가는 이미지 개수: 88 / 441
# Russula valid 파일에 들어가는 이미지 개수: 215 / 1073
# Suillus valid 파일에 들어가는 이미지 개수: 132 / 661
#
#
# Agaricus test 파일에 들어가는 이미지 개수: 195 / 975
# Amanita test 파일에 들어가는 이미지 개수: 150 / 749
# Boletus test 파일에 들어가는 이미지 개수: 212 / 1060
# Cortinarius test 파일에 들어가는 이미지 개수: 165 / 824
# Entoloma test 파일에 들어가는 이미지 개수: 164 / 821
# Exidia test 파일에 들어가는 이미지 개수: 85 / 425
# Hygrocybe test 파일에 들어가는 이미지 개수: 148 / 742
# Inocybe test 파일에 들어가는 이미지 개수: 110 / 551
# Lactarius test 파일에 들어가는 이미지 개수: 217 / 1087
# Pluteus test 파일에 들어가는 이미지 개수: 88 / 441
# ...

# %%
# train, valid, test 데이터셋을 나누는 함수
# img_list - 버섯 이미지 파일 리스트
# test_count - test dataset에 들어가는 이미지 개수
# valid_count - valid dataset에 들어가는 이미지 개수
# train_path - train dataset의 경로
# test_path - test dataset의 경로
# valid_path - valid dataset의 경로

def split(img_list, test_count, valid_count, train_path, test_path, valid_path):
  # image shuffle
  np.random.shuffle(img_list)

  test_files=[]
  valid_files=[]

  # test dataset 분리
  for i in random.sample(img_list, test_count):
    test_files.append(i)

  # test dataset에 포함되지 않은 data -> not_test_files (train + valid)
  # not_test_files에서 20%는 valid dataset, 60%는 train dataset으로 분리
  not_test_files = [x for x in img_list if x not in test_files]

  for i in random.sample(not_test_files, valid_count):
    valid_files.append(i)

  train_files = [x for x in not_test_files if x not in valid_files]

  # split한 data들을 train, test, valid 폴더로 복사
  for k in train_files:
    shutil.copy(k, train_path)

  for c in test_files:
    shutil.copy(c, test_path)

  for v in valid_files:
    shutil.copy(v, valid_path)

  print('train 폴더 이미지 개수: {}\nvalid 폴더 이미지 개수: {}\ntest 폴더 이미지 개수: {}\n'.format(len(glob.glob(train_path+'/*')), len(glob.glob(valid_path+'/*')), len(glob.glob(test_path+'/*'))))

# %%
for elem in mushrooms:
  globals()[elem+'_train_path'] = '/content/train/{}'.format(elem)
  globals()[elem+'_valid_path'] = '/content/valid/{}'.format(elem)
  globals()[elem+'_test_path'] = '/content/test/{}'.format(elem)
  split(globals()[elem], globals()[elem+'_test_count'], globals()[elem+'_valid_count'], globals()[elem+'_train_path'], globals()[elem+'_test_path'], globals()[elem+'_valid_path'])
# Out:
# train 폴더 이미지 개수: 585
# valid 폴더 이미지 개수: 195
# test 폴더 이미지 개수: 195
#
# train 폴더 이미지 개수: 449
# valid 폴더 이미지 개수: 150
# test 폴더 이미지 개수: 150
#
# train 폴더 이미지 개수: 636
# valid 폴더 이미지 개수: 212
# test 폴더 이미지 개수: 212
#
# train 폴더 이미지 개수: 494
# valid 폴더 이미지 개수: 165
# test 폴더 이미지 개수: 165
#
# train 폴더 이미지 개수: 493
# valid 폴더 이미지 개수: 164
# test 폴더 이미지 개수: 164
#
# train 폴더 이미지 개수: 255
# valid 폴더 이미지 개수: 85
# test 폴더 이미지 개수: 85
#
# train 폴더 이미지 개수: 446
# valid 폴더 이미지 개수: 148
# test 폴더 이미지 개수: 148
#
# train 폴더 이미지 개수: 331
# valid 폴더 이미지 개수: 110
# test 폴더 이미지 개수: 110
#
# train 폴더 이미지 개수: 653
# valid 폴더 이미지 개수: 217
# test 폴더 이미지 개수: 217
#
# train 폴더 이미지 개수: 265
# valid 폴더 이미지 개수: 88
# test 폴더 이미지 개수: 88
#
# train 폴더 이미지 개수: 643
# valid 폴더 이미지 개수: 215
# test 폴더 이미지 개수: 215
#
# train 폴더 이미지 개수: 397
# valid 폴더 이미지 개수: 132
# test 폴더 이미지 개수: 132

# %%
train_path = '/content/train'
test_path = '/content/test'
valid_path = '/content/valid'

# 이미지 resize
resize_trans = transforms.Compose([transforms.Resize((224, 224)),
                                  transforms.ToTensor(),
                                  ])

resize_train = datasets.ImageFolder(root=train_path, transform=resize_trans)
resize_test = datasets.ImageFolder(root=test_path, transform=resize_trans)
resize_valid = datasets.ImageFolder(root=valid_path, transform=resize_trans)

# %%
# data normaliztion
def get_mean_std(dataset):
  meanRGB = [np.mean(image.numpy(), axis=(1,2)) for image,_ in dataset]
  stdRGB = [np.std(image.numpy(), axis=(1,2)) for image,_ in dataset]

  meanR = np.mean([m[0] for m in meanRGB])
  meanG = np.mean([m[1] for m in meanRGB])
  meanB = np.mean([m[2] for m in meanRGB])

  stdR = np.mean([s[0] for s in stdRGB])
  stdG = np.mean([s[1] for s in stdRGB])
  stdB = np.mean([s[2] for s in stdRGB])

  print(meanR, meanG, meanB)
  print(stdR, stdG, stdB)

  mean = [meanR, meanG, meanB]
  std = [stdR, stdG, stdB]

  return mean, std

# %%
resize_train_mean, resize_train_std = get_mean_std(resize_train)
# Out:
# 0.40410244 0.38385987 0.29707754
# 0.22356634 0.20817377 0.2017793

# %%
resize_valid_mean, resize_valid_std = get_mean_std(resize_valid)
# Out:
# 0.408261 0.38537267 0.29836035
# 0.2229719 0.20722328 0.2007346

# %%
resize_test_mean, resize_test_std = get_mean_std(resize_test)
# Out:
# 0.4052403 0.38432524 0.29656914
# 0.22396314 0.20812556 0.20208429

# %%
transform_train = transforms.Compose([
    transforms.Resize((224, 224)), # 이미지 resize
    transforms.ToTensor(),
    transforms.Normalize(resize_train_mean, resize_train_std)
])

transform_valid = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.ToTensor(),
    transforms.Normalize(resize_valid_mean, resize_valid_std)
])

transform_test = transforms.Compose([
    transforms.Resize((224, 224)), 
    transforms.ToTensor(),
    transforms.Normalize(resize_test_mean, resize_test_std)
])

trainset = datasets.ImageFolder(root=train_path, transform=transform_train)
validset = datasets.ImageFolder(root=valid_path, transform=transform_valid)
testset = datasets.ImageFolder(root=test_path, transform=transform_test)

# hyperparameter - batch size를 변경할 수 있는 부분
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128,
                                          shuffle=True, num_workers=0)

validloader = torch.utils.data.DataLoader(validset, batch_size=128,
                                         shuffle=True, num_workers=0)

testloader = torch.utils.data.DataLoader(testset, batch_size=128,
                                         shuffle=True, num_workers=0)

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()
images.shape
# Out:
# torch.Size([128, 3, 224, 224])

# %%
# Freeze network
for param in model.parameters():
    param.requires_grad = False

# 순서를 갖는 모듈의 컨테이너
# 정의된 것과 같은 순서로 모든 모듈들을 통해 전달 -> 신경망을 빠르게 제작
# 참고: https://tutorials.pytorch.kr/beginner/basics/buildmodel_tutorial.html
# nn.Linear(input_dim, output_dim)
# nn.ReLu() - 선형 변환 후에 적용되어 비선형성을 도입
# nn.Dropout() - dropout layer를 추가
# nn.LogSoftmax - 신경망의 마지막 선형 계층을 전달받아 logits을 반환

# 데이터셋의 클래스 개수
num_classes = 12

model.fc = nn.Sequential(nn.Linear(2048, 512),
                                 nn.ReLU(),
                                 nn.Dropout(0.3),
                                 nn.Linear(512, num_classes),
                                 nn.LogSoftmax(dim=1)
                                )
# loss function
criterion = torch.nn.CrossEntropyLoss()

optimizer = optim.Adam(model.fc.parameters(), lr=0.002, weight_decay=0.0)
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda epoch: 0.95 ** epoch)

model.to(device) # NeuralNetwork의 인스턴스를 생성하고 이를 device로 이동한 뒤, 구조를 출력
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
epochs = 30
steps = 0
running_loss = 0
print_every = 30
train_losses, val_losses, train_accs, val_accs = [], [], [], []

for epoch in range(epochs):
    print(f'lr: {optimizer.param_groups[0]["lr"]:.4f}')
    epoch_loss = 0
    epoch_accuracy = 0
    epoch_val_accuracy = 0
    epoch_val_loss = 0

    for data, label in trainloader:
        data = data.to(device)
        label = label.to(device)

        output = model(data)
        loss = criterion(output, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (output.argmax(dim=1) == label).float().mean()
        epoch_accuracy += acc / len(trainloader)
        epoch_loss += loss / len(trainloader)

    if steps % print_every == 0:
      with torch.no_grad():

          for data, label in validloader:
              data = data.to(device)
              label = label.to(device)

              val_output = model(data)
              val_loss = criterion(val_output, label)

              acc = (val_output.argmax(dim=1) == label).float().mean()
              epoch_val_accuracy += acc / len(validloader)
              epoch_val_loss += val_loss / len(validloader)
              
      
      print(
          f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - acc: {epoch_accuracy:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f}\n"
      )
      model.train()

      train_losses.append(epoch_loss)
      val_losses.append(epoch_val_loss)
      train_accs.append(epoch_accuracy)
      val_accs.append(epoch_val_accuracy)
      
    scheduler.step()

torch.save(model, 'aerialmodel.pth')
# Out:
# lr: 0.0020
# Epoch : 1 - loss : 1.8399 - acc: 0.4053 - val_loss : 1.3227 - val_acc: 0.5603
#
# lr: 0.0019
# Epoch : 2 - loss : 1.1809 - acc: 0.6002 - val_loss : 1.1644 - val_acc: 0.6160
#
# lr: 0.0018
# Epoch : 3 - loss : 1.0722 - acc: 0.6419 - val_loss : 1.1260 - val_acc: 0.6197
#
# lr: 0.0017
# Epoch : 4 - loss : 0.9785 - acc: 0.6670 - val_loss : 1.0630 - val_acc: 0.6364
#
# lr: 0.0016
# Epoch : 5 - loss : 0.9323 - acc: 0.6787 - val_loss : 1.1816 - val_acc: 0.6024
#
# lr: 0.0015
# Epoch : 6 - loss : 0.9188 - acc: 0.6909 - val_loss : 1.0212 - val_acc: 0.6602
#
# lr: 0.0015
# Epoch : 7 - loss : 0.8305 - acc: 0.7147 - val_loss : 1.0180 - val_acc: 0.6666
#
# lr: 0.0014
# Epoch : 8 - loss : 0.7747 - acc: 0.7383 - val_loss : 0.9958 - val_acc: 0.6745
#
# lr: 0.0013
# Epoch : 9 - loss : 0.7522 - acc: 0.7445 - val_loss : 1.0058 - val_acc: 0.6755
#
# lr: 0.0013
# Epoch : 10 - loss : 0.7345 - acc: 0.7498 - val_loss : 1.0172 - val_acc: 0.6696
#
# lr: 0.0012
# ...

# %%
print(train_losses)
print(val_losses)
# Out:
# [tensor(1.8399, device='cuda:0', grad_fn=<AddBackward0>), tensor(1.1809, device='cuda:0', grad_fn=<AddBackward0>), tensor(1.0722, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.9785, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.9323, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.9188, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.8305, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.7747, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.7522, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.7345, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.7269, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.6712, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.6536, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.6208, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.5988, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.5646, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.5447, device='cuda:0', grad_fn=<AddBackward0>), tensor(0.5354, device='cuda:
# ...

# %%
train_losses = [elem.item() for elem in train_losses]
val_losses = [elem.item() for elem in val_losses]

plt.plot(train_losses, label='Train loss')
plt.plot(val_losses, label='validation loss')
plt.legend(frameon=False)
plt.show()

# %%
print(train_accs)
print(val_accs)
# Out:
# [tensor(0.4053, device='cuda:0'), tensor(0.6002, device='cuda:0'), tensor(0.6419, device='cuda:0'), tensor(0.6670, device='cuda:0'), tensor(0.6787, device='cuda:0'), tensor(0.6909, device='cuda:0'), tensor(0.7147, device='cuda:0'), tensor(0.7383, device='cuda:0'), tensor(0.7445, device='cuda:0'), tensor(0.7498, device='cuda:0'), tensor(0.7469, device='cuda:0'), tensor(0.7621, device='cuda:0'), tensor(0.7761, device='cuda:0'), tensor(0.7870, device='cuda:0'), tensor(0.7973, device='cuda:0'), tensor(0.8105, device='cuda:0'), tensor(0.8155, device='cuda:0'), tensor(0.8142, device='cuda:0'), tensor(0.8276, device='cuda:0'), tensor(0.8292, device='cuda:0'), tensor(0.8356, device='cuda:0'), tensor(0.8485, device='cuda:0'), tensor(0.8514, device='cuda:0'), tensor(0.8603, device='cuda:0'), tensor(0.8623, device='cuda:0'), tensor(0.8647, device='cuda:0'), tensor(0.8650, device='cuda:0'), tensor(0.8804, device='cuda:0'), tensor(0.8829, device='cuda:0'), tensor(0.8844, device='cuda:0')]
# ...

# %%
train_accs = [elem.item() for elem in train_accs]
val_accs = [elem.item() for elem in val_accs]
plt.plot(train_accs, label='Training accuracy')
plt.plot(val_accs, label='val accuracy')
plt.legend(frameon=False)
plt.show()

# %%
test_dir = "/content/test/"
test_transforms = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor()])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model=torch.load('aerialmodel.pth')
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
accuracy = 0.0
    
with torch.no_grad():
    for data,label in testloader:
        data = data.to(device)
        label = label.to(device)
        outputs = model(data)
        acc = (outputs.argmax(dim=1) == label).float().mean()
        accuracy += acc / len(testloader)

print(f"accuracy: {accuracy:.4f}\n")
# Out:
# accuracy: 0.7228

# %%
def predict_image(image):
    image_tensor = test_transforms(image).float()
    image_tensor = image_tensor.unsqueeze_(0)
    input = image_tensor
    input = input.to(device)
    output = model(input)
    index = output.data.cpu().numpy().argmax()
    return index

# %%
def get_random_images(num):
    data = datasets.ImageFolder(test_dir, transform=test_transforms)
    classes = data.classes
    indices = list(range(len(data)))
    np.random.shuffle(indices)
    idx = indices[:num]
    from torch.utils.data.sampler import SubsetRandomSampler
    sampler = SubsetRandomSampler(idx)
    loader = torch.utils.data.DataLoader(data, 
                   sampler=sampler, batch_size=num)
    dataiter = iter(loader)
    images, labels = dataiter.next()
    return images, labels

# %%
import PIL
from PIL import Image,ImageDraw,ImageFont
import os
classes = trainloader.dataset.classes
to_pil = transforms.ToPILImage()
images, labels = get_random_images(5)
fig=plt.figure(figsize=(20,20))

for ii in range(len(images)):
    image = to_pil(images[ii])
    index = predict_image(image)
    sub = fig.add_subplot(1, len(images), ii+1)
    res = int(labels[ii]) == index
    sub.set_title(str(classes[index]) + ":" + str(res) + "     ")
    plt.axis('off')
    plt.imshow(image)
    draw =ImageDraw.Draw(image)
plt.show()

# %%
classes = trainloader.dataset.classes
to_pil = transforms.ToPILImage()
images, labels = get_random_images(5)
fig=plt.figure(figsize=(20,20))
for ii in range(len(images)):
    image = to_pil(images[ii])
    index = predict_image(image)
    sub = fig.add_subplot(1, len(images), ii+1)
    res = int(labels[ii]) == index
    print(classes[index])
    plt.axis('off')
    
    
    plt.imshow(image)
    if (str(classes[index]) == ('Agaricus')): 
      sub.set_title(str(classes[index]) + ": " + "non-posion")
    elif(classes[index] =='Amanita'):
      sub.set_title(str(classes[index]) + ": " + "posion ")
    elif(classes[index] =='Boletus'):
      sub.set_title(str(classes[index]) + ": " + "posion ")
    elif(classes[index] =='Cortinarius'):
      sub.set_title(str(classes[index]) + ": " + "posion ")
    elif(classes[index] =='Entoloma'):
      sub.set_title(str(classes[index]) + ": " + "non-posion ")
    elif(classes[index] =='Exidia'):
      sub.set_title(str(classes[index]) + ": " + "posion ")
    elif(classes[index] =='Hygrocybe'):
      sub.set_title(str(classes[index]) + ": " + "non-posion ")
    elif(classes[index] =='Inocybe'):
      sub.set_title(str(classes[index]) + ": " + "posion ")
    elif(classes[index] =='Lactarius'):
      sub.set_title(str(classes[index]) + ": " + "non-posion ")
    elif(classes[index] =='Pluteus'):
      sub.set_title(str(classes[index]) + ": " + "non-posion ")
    elif(classes[index] =='Russula'):
      sub.set_title(str(classes[index]) + ": " + "posion ")
    elif(classes[index] =='Suillus'):
      sub.set_title(str(classes[index]) + ": " + "non-poison ")

plt.show()
# Out:
# Pluteus
# Pluteus
# Agaricus
# Entoloma
# Pluteus
